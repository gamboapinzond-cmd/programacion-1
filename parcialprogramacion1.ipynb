# %% [markdown]
# <a href="https://colab.research.google.com/github/gamboapinzond-cmd/programacion-1/blob/main/parcialprogramacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = {1,2,3,4,5}
B = {2,1,5}

# %%
A.difference(B)
# Out:
# {3, 4}

# %% [markdown]
# #esta sentencia analiza los valores enteros de de cada conjunto y separa los valores enteros que no tienen en comun cada conunto y crea otro conjunto con los valores que que diferencian a un conjunto del otro

# %%
A.symmetric_difference(B)
# Out:
# {3, 4}

# %%
conjuntoA = {1,2,3,4,5,6}
conjuntoB = {1,2,3,4,5}
conjuntoA.issuperset(B)
# Out:
# True

# %% [markdown]
# este comando me evalua si todos los elementos del conjunto B estan contenidos en el conjunto A y su salida es un valor booleano true/false

# %%
conjuntoA.isdisjoint(B)
# Out:
# False

# %% [markdown]
# este metodo me evalua si ninguno de los elementos del conjunto B estan contenidos en el conjunto A. y como no es asi nos da un valor booleano que en este caso es false

# %%
datos2 = {1:"uno",2:"dos"}

# %%
datos2.update({3:"tres"})
datos2
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres'}

# %% [markdown]
# este metodo lo que hace es agregar un elemnto mas a un diccionario ya existente, hay que colocar valor y clave

# %%
datos2.update({4:"uno"})
datos2
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres', 4: 'uno'}

# %%
datos2
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres'}

# %% [markdown]
# al agregar una clave:valor repetida, el metodo sigue modificando y reescribiendo el diccionario sin que de algun error

# %%
datos3 = {5:"cinco",6:"seis",7:"siete",8:"ocho"}
datos3.setdefault(9,"nueve")
datos3
# Out:
# {5: 'cinco', 6: 'seis', 7: 'siete', 8: 'ocho', 9: 'nueve'}

# %%
datos3.setdefault(5:"veinte")
# Out:
#   File "/tmp/ipykernel_723/2802952546.py", line 1
#     datos3.setdefault(5:"veinte")
#                        ^
# SyntaxError: invalid syntax

# %%
datos3.setdefault(5:"cinco")
# Out:
#   File "/tmp/ipykernel_723/4257123535.py", line 1
#     datos3.setdefault(5:"cinco")
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# el metodo setdefault lo que hace es agregr un valor al diccionario si y solo si ese valor (clave,valor) no esten repetidos ( que no este repetida ni la clave ni el valor) de lo contrario nos dara un error

# %% [markdown]
# parte III

# %%
m = (input("Ingrese un número natural: "))
if isinstance(m, int) and m >= 0:
   for n in range(0, (m+1)):
     if n == 1 or n == 0:
        print("El número es ", n)
     else:
      for x in range(2, n):
        if n % x == 0:
         print(n, 'es igual a', x, '*', n // x)
        break
    else: # Este else corresponde al for, no al if
      print(n, 'es un número primo')
else:
print("El número no es natural")
# Out:
#   File "<tokenize>", line 11
#     else: # Este else corresponde al for, no al if
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
def naturaloprimo(m):
  m = int(("Ingrese un número natural: ",))
  try
  m = int(m)
  except:
    print("El número no es natural")
  if isinstance(m, int) and m >= 0:
    for n in range(0, (m+1)):
      if n == 1 or n == 0:
        print("El número es ", n)
      else:
        for x in range(2, n):
          if n % x == 0:
            print(n, 'es igual a', x, '*', n // x)
            break
        else:
          print(n, 'es un número primo')
  else:
    print("El número no es natural")

# %% [markdown]
# la funcion lo que hace es verificar si el valor de entrada que ingresamos es int o str, si es str el programa pide que ingrese un nunero natural, si el ususario ingreso un numero negativo va a decir wque el numero no es natural, y si es natual va a verificar si es primo o no

# %%
naturaloprimo(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_723/401636170.py in <cell line: 0>()
# ----> 1 naturaloprimo(2)
#
# /tmp/ipykernel_723/2895417816.py in naturaloprimo(m)
#       1 def naturaloprimo(m):
# ----> 2   m = int(input(float("Ingrese un número natural: ",)))
#       3   if isinstance(m, int) and m >= 0:
#       4     for n in range(0, (m+1)):
#       5       if n == 1 or n == 0:
#
# ValueError: could not convert string to float: 'Ingrese un número natural: '

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
# help> isinstance
# Help on built-in function isinstance in module builtins:
#
# isinstance(obj, class_or_tuple, /)
#     Return whether an object is an instance of a class or of a subclass thereof.
#
#     A tuple, as in ``isinstance(x, (A, B, ...))``, may be given as the target to
# ...

# %%
def contadordevocalesyconsonantes():
  vocales = "a,e,i,o,u"
  consonantes = "bcdfghjklmnñpqrstvwxyz"
