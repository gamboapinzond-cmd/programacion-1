# %% [markdown]
# <a href="https://colab.research.google.com/github/gamboapinzond-cmd/programacion-1/blob/main/hola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile pedirnotas.py
def pedir_nombre():
  return input("ingrese el nombre del estudiante ")


def notas_():
  n1 = float(input("ingrese la nota 1 "))
  n2 = float(input("ingrese la nota 2 "))
  n3 = float(input("ingrese la nota 3 "))
  return n1, n2, n3
# Out:
# Overwriting pedirnotas.py

# %%
# %%writefile promedio.py

def calcular_promedio(n1, n2, n3):
  return (n1 + n2 + n3) / 3
# Out:
# Overwriting promedio.py

# %%
import pedirnotas
nombre = pedirnotas.pedir_nombre()
# Out:
# ingrese el nombre del estudiante juan

# %%
import importlib
importlib.reload(pedirnotas)
notas = pedirnotas.notas_()
# Out:
# ingrese la nota 1 4
# ingrese la nota 2 1
# ingrese la nota 3 3

# %%
list(notas)
# Out:
# [33.0, 3.0, 3.0]

# %%
import promedio

# %%
import promedio
prom = promedio.calcular_promedio(notas[0],notas[1],notas[2])
print("estudiante: ", nombre)
print("promedio: ", prom)

if prom >= 3 :
  print("aprobo")
else:
  print("reprobo")
# Out:
# estudiante:  juan
# promedio:  2.6666666666666665
# reprobo
