# %% [markdown]
# <a href="https://colab.research.google.com/github/gamboapinzond-cmd/programacion-1/blob/main/piton_clase_semana_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print()

# %%
print("ADIVINA EL NÚMERO")
print("(Entre 1 y 5, escribe 0 para salir)")

numero_secreto = 3
numero_intentos = 2

while numero_intentos>0:

    intento = int(input("Adivina: "))
    if intento == 0:
        print("¡Hasta luego!")
        break
    if intento < 1 or intento > 5:
        print("Número fuera de rango, intenta de nuevo")
        continue
    if intento == numero_secreto:
        print("¡Correcto! Adivinaste")
        break
    else:
        if numero_intentos > 0:
            numero_intentos -= 1
            print(f"Quedan {numero_intentos} intentos")
        else:
            print("Te quedaste sin intentos")

# %%
print("ADIVINA EL NÚMERO")
print("(Entre 1 y 5, escribe 0 para salir)")

numero_secreto = 3
numero_intentos = 2

while numero_intentos>0:

    intento = int(input("Adivina: "))
    if intento == 0:
        print("¡Hasta luego!")
        break
    elif intento < 1 or intento > 5:
        numero_intentos -= 1
        if numero_intentos > 0:
            print(f" numero incorrecto. 3                            Quedan {numero_intentos} intentos")
        else:
            print("Te quedaste sin intentos")
        continue
    elif intento == numero_secreto:
        print("¡Correcto! Adivinaste")
        break
    else:
        if numero_intentos > 0:
            numero_intentos -= 1
            print(f"Quedan {numero_intentos} intentos")
        else:
            print("Te quedaste sin intentos")
# Out:
# ADIVINA EL NÚMERO
# (Entre 1 y 5, escribe 0 para salir)
# Adivina: 32
#  numero incorrecto. Quedan 1 intentos
# Adivina: 2
# Quedan 0 intentos

# %%
def saludar():
  "la funcion que te saluda"
  print("hola mundo")

# %%
saludar()
# Out:
# hola mundo

# %%
saludar
# Out:
# <function __main__.saludar()>

# %%
def area():
  "la funcion que calcul el area de unntrangulo"
  a = int(input("ingresa la base: "))
  b = int(input("ingresa la altura: "))
  print("el area del triangulon es",((a)*(b))/2)

# %%
area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-404/3205345536.py in <cell line: 0>()
# ----> 1 area(2)
#
# TypeError: area() takes 0 positional arguments but 1 was given

# %%
saludar
# Out:
# <function __main__.saludar()>

# %%
def saludar(nombre = "estudiante"):
  print("que paso", nombre)

saludar()
saludar(nombre = "juan")
# Out:
# que paso estudiante
# que paso juan

# %%
def multiplicacion(numero = int(input("ingresa un numero"))):
  print("el numero multiplicado por 5 es...", numero*5)
  print("el resultado de la multiplicacion elevado al cuadrado es...", (numero*5)**2)

multiplicacion()
# Out:
# ingresa un numero20
# el numero multiplicado por 5 es... 100
# el resultado de la multiplicacion elevado al cuadrado es... 10000
