# %% [markdown]
# <a href="https://colab.research.google.com/github/gamboapinzond-cmd/programacion-1/blob/main/Tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- CÓDIGO ORIGINAL DEL VIDEO ---
nombre = input("¿Cual es tu nombre? ")
print("Hola " + nombre)

año_nacimiento = input("Ingresa tu año de nacimiento: ")
edad = 2024 - int(año_nacimiento)
print("Tienes", edad, "años")


# mi codigo
user_name = input("Introduce tu nombre completo: ")
print(f"Registro exitoso: {user_name.upper()}")

nacimiento = int(input("Año de nacimiento: "))
año_actual = 2026
edad_calculada = año_actual - nacimiento
dias_vividos = edad_calculada * 365

print(f"Hola {user_name}, tienes aproximadamente {dias_vividos} días de vida.")
# Out:
# ¿Cual es tu nombre? Diego
# Hola Diego
# Ingresa tu año de nacimiento: 2008
# Tienes 16 años
# Introduce tu nombre completo: Diego gamboa
# Registro exitoso: DIEGO GAMBOA
# Año de nacimiento: 2008
# Hola Diego gamboa, tienes aproximadamente 6570 días de vida.

# %%
# codigo original
numeros = [1, 2, 3, 4, 5]
numeros.append(6)
for n in numeros:
    print(n)

# mi codigo
materias = ["matemáticas", "programación", "física", "humanidades"]
materias_largas = []

for materia in materias:
    # Si la materia tiene más de 6 letras, la pasamos a mayúscula
    if len(materia) > 6:
        materias_largas.append(materia.capitalize())

print("Materias con nombres largos identificadas:")
print(materias_largas)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# Materias con nombres largos identificadas:
# ['Matemáticas', 'Programación', 'Humanidades']
